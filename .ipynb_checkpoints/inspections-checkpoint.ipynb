# %%
import pandas as pd
import pymongo

# %%
csv_file = 'resources/food_inspections.csv'
inspections = pd.read_csv(csv_file)
inspections[inspections['City']=='Chicago']
inspections
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-c993732c28e5> in <module>
#       1 csv_file = 'resources/food_inspections.csv'
# ----> 2 inspections = pd.read_csv(csv_file)
#       3 inspections[inspections['City']=='Chicago']
#       4 inspections
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     695                     skip_blank_lines=skip_blank_lines)
#     696
# --> 697         return _read(filepath_or_buffer, kwds)
#     698
#     699     parser_f.__name__ = name
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     422
#     423     # Create the parser.
# --> 424     parser = TextFileReader(filepath_or_buffer, **kwds)
#     425
#     426     if chunksize or iterator:
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     888             self.options['has_index_names'] = kwds['has_index_names']
#     889
# --> 890         self._make_engine(self.engine)
#     891
#     892     def close(self):
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1115     def _make_engine(self, engine='c'):
#    1116         if engine == 'c':
# -> 1117             self._engine = CParserWrapper(self.f, **self.options)
#    1118         else:
#    1119             if engine == 'python':
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1846         kwds['usecols'] = self.usecols
#    1847
# -> 1848         self._reader = parsers.TextReader(src, **kwds)
#    1849         self.unnamed_cols = self._reader.unnamed_cols
#    1850
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'resources/food_inspections.csv' does not exist: b'resources/food_inspections.csv'

# %%
inspections_edit = inspections[['AKA Name', 'License #', 'Facility Type', 'Inspection Date', 
                                'Results', 'Latitude', 'Longitude']]
inspections_transform = inspections_edit.rename(columns={
    'AKA Name': 'name',
    'License #': 'License #',
    'Facility Type': 'Facility Type',
    'Inspection Date': 'Inspection Date',
    'Results': 'Results',
    'Latitude': 'latitude',
    'Longitude': 'longitude'
})
inspections_transform.head()
# Out:
#                       name  License #   Facility Type Inspection Date  \
# 0  MARRIOT MARQUIS CHICAGO  2517328.0      Restaurant         8/28/17
# 1              JET'S PIZZA  2522268.0      Restaurant         8/28/17
# 2                ROOM 1520  2446638.0   Special Event         8/28/17
# 3  MARRIOT MARQUIS CHICAGO  2517338.0      Restaurant         8/28/17
# 4  CICS WEST BELDEN CAMPUS  2549079.0  CHARTER SCHOOL         8/28/17
#
#      Results   latitude  longitude
# 0       Pass  41.853651 -87.620534
# 1  Not Ready  41.881572 -87.653052
# 2  Not Ready  41.886577 -87.665328
# 3       Pass  41.853651 -87.620534
# 4       Pass  41.921675 -87.776711

# %%
inspections_transform.groupby('License #').head()
# Out:
#                                                  name  License #  \
# 0                             MARRIOT MARQUIS CHICAGO  2517328.0
# 1                                         JET'S PIZZA  2522268.0
# 2                                           ROOM 1520  2446638.0
# 3                             MARRIOT MARQUIS CHICAGO  2517338.0
# 4                             CICS WEST BELDEN CAMPUS  2549079.0
# 5                               SHRIMP'S FISH CHICKEN  2549497.0
# 6                                     ART'S DRIVE INN    64682.0
# 7                                             VINCENT    51614.0
# 8                           CAPTAIN HOOKS OF DAN RYAN  2192934.0
# 9                                    JIBARITO'S Y MAS  2452249.0
# 10                       HAROLDS CHICKEN WEST LOOP 47  2543388.0
# 11                                 THE ART OF CHICKEN  2202818.0
# 12                                 PHO 777 RESTAURANT  1473214.0
# 13                                CARNICERIA RUIZ INC    31999.0
# 14                                      CHICAGO KALBI    36111.0
# 15                                      FULL SHILLING    32813.0
# 16                                             SUBWAY  1516132.0
# 17                            JEFFERY BIG MARKET INC.  2374658.0
# 18                       KATHERINE  ANNE  CONFECTIONS  2247022.0
# 19                      NANCY'S HOME OF STUFFED PIZZA     7778.0
# 20                             MI TIENDITA QUICK MART  2551388.0
# 21                                    KAMAYAN EXPRESS  2412016.0
# 22                                          CHARLIE'S  1441898.0
# 23                                  MARY CRANE LEAGUE  2245628.0
# 24                                       SIAM COUNTRY  1768994.0
# 25                                        MR. HOT ONE  2483654.0
# 26                             NATURE FOUNTAIN HEALTH  2516912.0
# 27                         NARY'S GRILL & PIZZA, INC.  2551263.0
# 28                    BRASERITOS BUFFET &  RESTAURANT  2550985.0
# 29                                NARYS GRILL & PIZZA    72128.0
# ...                                               ...        ...
# 153750                                 SUNSET LIQUORS    13541.0
# 153753                                 ABE'S IN & OUT  1948539.0
# 153754                             DONS PIZZA & GRILL  1992130.0
# 153757                     CHICAGO SINAI CONGREGATION    75567.0
# 153759                        SAFAH FOOD & LIQUOR INC    14103.0
# 153761                                RAINBOW GROCERY    61801.0
# 153762                                            NaN  2004238.0
# 153766                   IZUMI SUSHI BAR & RESTAURANT  1357260.0
# 153767                                     MAKIA FOOD  2009488.0
# 153768          FUNSTON ELEMENTARY SCH. MAIN BUILDING  2112648.0
# 153772               FERNANDO'S MEXICAN GRILL & PIZZA  1915768.0
# 153776                                WALGREENS #1417    18584.0
# 153777                                   THE DOGHOUSE  1681450.0
# 153779                             CVS PHARMACY #2935  1998048.0
# 153781                                            NaN  2013344.0
# 153782                 REBECCA K. CROWN CHLD. DEV. CT    25814.0
# 153787  LOVEBUGS, TODDLER PROGRAMS AND PRESCHOOL, LLC  1820997.0
# 153791  LOVEBUGS, TODDLER PROGRAMS AND PRESCHOOL, LLC  1916128.0
# 153792                                          CITGO  2013296.0
# 153793                                            NaN  2002536.0
# 153796                                       7-ELEVEN  1766212.0
# 153797                           THE LEARNING TREE II  1869843.0
# 153798                      MONTICELLO FOOD MART, INC  2013259.0
# 153800                     SUPER DOG'S SUBMARINES INC  2008759.0
# 153801                     State Street Pizza Company  2009348.0
# 153803                                  WHIPPLE STORE  2009114.0
# 153804                                        TROQUET  1992040.0
# 153806                   DUNKIN DONUTS/BASKIN-ROBBINS  1380279.0
# 153807                                       Cafe 608  2013328.0
# 153808                                    mr.daniel's  1899292.0
#
#                           Facility Type Inspection Date             Results  \
# 0                            Restaurant         8/28/17                Pass
# 1                            Restaurant         8/28/17           Not Ready
# 2                         Special Event         8/28/17           Not Ready
# 3                            Restaurant         8/28/17                Pass
# 4                        CHARTER SCHOOL         8/28/17                Pass
# 5                            Restaurant         8/28/17                Fail
# 6                            Restaurant         8/25/17                Fail
# 7                            Restaurant         8/25/17                Fail
# 8                            Restaurant         8/25/17                Pass
# 9                            Restaurant         8/25/17     Out of Business
# 10                           Restaurant         8/25/17                Pass
# 11                           Restaurant         8/25/17            No Entry
# 12                           Restaurant         8/25/17                Fail
# 13                        Grocery Store         8/25/17                Pass
# 14                           Restaurant         8/25/17                Pass
# 15                           Restaurant         8/25/17                Fail
# 16                           Restaurant         8/25/17                Pass
# 17                        Grocery Store         8/25/17  Pass w/ Conditions
# 18                               Bakery         8/25/17                Pass
# 19                           Restaurant         8/25/17                Fail
# 20                        Grocery Store         8/25/17                Pass
# 21                           Restaurant         8/25/17            No Entry
# 22                        Grocery Store         8/25/17                Pass
# 23                   Daycare Combo 1586         8/25/17            No Entry
# 24                           Restaurant         8/25/17                Pass
# 25                           Restaurant         8/25/17  Pass w/ Conditions
# 26                           Restaurant         8/25/17                Pass
# 27                           Restaurant         8/25/17                Pass
# 28                           Restaurant         8/25/17                Fail
# 29                           Restaurant         8/25/17     Out of Business
# ...                                 ...             ...                 ...
# 153750                    Grocery Store          1/5/10                Pass
# 153753                    Grocery Store          1/5/10                Pass
# 153754                       Restaurant          1/5/10                Pass
# 153757            Daycare (2 - 6 Years)          1/5/10                Fail
# 153759                    Grocery Store          1/5/10                Pass
# 153761                    Grocery Store          1/5/10                Pass
# 153762                    Grocery Store          1/5/10                Fail
# 153766                       Restaurant          1/5/10                Fail
# 153767                              NaN          1/5/10                Pass
# 153768                           School          1/5/10                Pass
# 153772                       Restaurant          1/5/10                Pass
# 153776                    Grocery Store          1/5/10                Pass
# 153777                              NaN          1/5/10                Pass
# 153779                    Grocery Store          1/5/10                Pass
# 153781                       Restaurant          1/5/10                Fail
# 153782            Daycare (2 - 6 Years)          1/5/10                Pass
# 153787                              NaN          1/5/10                Pass
# 153791            Daycare (2 - 6 Years)          1/5/10                Pass
# 153792                    Grocery Store          1/5/10                Fail
# 153793            Daycare (2 - 6 Years)          1/5/10                Pass
# 153796                    Grocery Store          1/5/10                Pass
# 153797  Daycare Above and Under 2 Years          1/5/10                Pass
# 153798                    Grocery Store          1/5/10                Fail
# 153800                       Restaurant          1/5/10                Fail
# 153801                       Restaurant          1/5/10                Pass
# 153803                    Grocery Store          1/5/10                Fail
# 153804                       Restaurant          1/4/10                Pass
# 153806                       Restaurant          1/4/10                Pass
# 153807                       Restaurant          1/4/10                Pass
# 153808                       Restaurant          1/4/10                Pass
#
#          latitude  longitude
# 0       41.853651 -87.620534
# 1       41.881572 -87.653052
# 2       41.886577 -87.665328
# 3       41.853651 -87.620534
# 4       41.921675 -87.776711
# 5       41.815197 -87.606531
# 6       41.910601 -87.661863
# 7       41.979744 -87.667738
# 8       41.736030 -87.629095
# 9       41.924770 -87.712170
# 10      41.881372 -87.664663
# 11      41.918742 -87.687301
# 12      41.973167 -87.657438
# 13      41.935792 -87.707384
# 14      41.968409 -87.722769
# 15      41.949706 -87.658701
# 16      41.806572 -87.742977
# 17      41.766359 -87.575567
# 18      41.917386 -87.696585
# 19      41.935810 -87.644404
# 20      41.768542 -87.722651
# 21      41.975717 -87.679246
# 22      41.961114 -87.702587
# 23      41.934280 -87.682908
# 24      41.966232 -87.678966
# 25      41.779421 -87.674242
# 26      41.917443 -87.712715
# 27      41.816597 -87.700393
# 28      41.909736 -87.729273
# 29      41.816597 -87.700393
# ...           ...        ...
# 153750  41.901910 -87.773905
# 153753  41.853573 -87.717254
# 153754  41.901914 -87.773632
# 153757  41.899022 -87.628924
# 153759  41.764896 -87.653965
# 153761  41.768328 -87.673819
# 153762  41.751655 -87.580828
# 153766  41.884301 -87.646953
# 153767  41.846516 -87.695423
# 153768  41.917621 -87.716929
# 153772  42.011357 -87.806788
# 153776  41.852084 -87.674651
# 153777  42.008536 -87.914428
# 153779  41.736482 -87.585784
# 153781  41.823504 -87.650666
# 153782  41.757099 -87.564978
# 153787  41.905866 -87.643136
# 153791  41.905866 -87.643136
# 153792  41.685026 -87.642297
# 153793  41.736849 -87.582488
# 153796  41.883132 -87.634007
# 153797  41.742993 -87.721558
# 153798  41.899186 -87.717804
# 153800  41.706852 -87.658946
# 153801  41.889319 -87.628153
# 153803  41.959489 -87.704380
# 153804  41.961606 -87.675967
# 153806  41.884586 -87.631010
# 153807  41.938007 -87.644755
# 153808  41.938443 -87.768318
#
# [102497 rows x 7 columns]

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-0d68fe8c78ee> in <module>
#       1 conn = 'mongodb://localhost:27017'
# ----> 2 client = pymongo.MongClient(conn)
#
# AttributeError: module 'pymongo' has no attribute 'MongClient'
