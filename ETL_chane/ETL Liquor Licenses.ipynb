# %%
#import tools necessary to complete project
import pandas as pd
from sqlalchemy import create_engine
import pymongo
import numpy as np

# %%
#read CSV file and bring into pandas
liquor_csv = "chicago_liquor_licenses1.csv"
liquor_license_df = pd.read_csv(liquor_csv)
liquor_license_df.head()
# Out:
#                  ID LICENSE ID  ACCOUNT NUMBER  SITE NUMBER  \
# 0  2550239-20170804  2,550,239          309467            1
# 1  2550220-20180616  2,594,440          407124            1
# 2  2550238-20170804  2,550,238          307009            1
# 3  2550234-20180916  2,613,206          336442            1
# 4  2550215-20181016  2,620,387          401984            2
#
#                                 LEGAL NAME  DOING BUSINESS AS NAME  \
# 0              CORK SPECIAL EVENTS COMPANY  CORKY'S CATERING, INC.
# 1  COUNTRY HOUSE RESTAURANT of ALSIP, INC.           COUNTRY HOUSE
# 2                   BUONA CATERING, L.L.C.           BEYOND EVENTS
# 3                    D'MASTI CATERING INC.        D'MASTI CATERING
# 4                        RAVEN'S PLACE LLC  RAVEN'S PLACE CATERING
#
#                  ADDRESS         CITY STATE  ZIP CODE  ...  \
# 0       1421 W FULLERTON      ADDISON    IL   60101.0  ...
# 1      5400 W 127TH ST 1        ALSIP    IL   60807.0  ...
# ...

# %%
#rename rows to lower case
liquor_license_df = liquor_license_df.rename(
    columns=str.lower
)
liquor_license_df.head()
# Out:
#                  id license id  account number  site number  \
# 0  2550239-20170804  2,550,239          309467            1
# 1  2550220-20180616  2,594,440          407124            1
# 2  2550238-20170804  2,550,238          307009            1
# 3  2550234-20180916  2,613,206          336442            1
# 4  2550215-20181016  2,620,387          401984            2
#
#                                 legal name  doing business as name  \
# 0              CORK SPECIAL EVENTS COMPANY  CORKY'S CATERING, INC.
# 1  COUNTRY HOUSE RESTAURANT of ALSIP, INC.           COUNTRY HOUSE
# 2                   BUONA CATERING, L.L.C.           BEYOND EVENTS
# 3                    D'MASTI CATERING INC.        D'MASTI CATERING
# 4                        RAVEN'S PLACE LLC  RAVEN'S PLACE CATERING
#
#                  address         city state  zip code  ...  \
# 0       1421 W FULLERTON      ADDISON    IL   60101.0  ...
# 1      5400 W 127TH ST 1        ALSIP    IL   60807.0  ...
# ...

# %%
#remove rows of locations that are not in the city of Chicago
liquor_license_df = liquor_license_df[liquor_license_df['city']=='CHICAGO']
liquor_license_df.head()
# Out:
#                  id license id  account number  site number  \
# 5  2550102-20170803  2,550,102          408343            1
# 6  2423997-20170619  2,423,997          401191            1
# 7  1800741-20170316  2,507,270           11400            1
# 8  1739261-20170316  2,509,086          307041            1
# 9  1226890-20170316  2,508,287          201786            1
#
#                legal name      doing business as name  \
# 5       VOICE OF THE CITY           VOICE OF THE CITY
# 6             MAGO RC LLC        MAGO GRILL & CANTINA
# 7  FORTNIGHTLY OF CHICAGO  THE FORTNIGHTLY OF CHICAGO
# 8     MCCLURG CORPORATION                   7- ELEVEN
# 9        3343 CLARK CORP.                  LOWCOUNTRY
#
#                             address     city state  zip code  ...  \
# 5  3429 W DIVERSEY AVE 2ND/REAR 209  CHICAGO    IL   60647.0  ...
# 6      1010 S DELANO WEST CT 1 G131  CHICAGO    IL   60605.0  ...
# 7                 120 E BELLEVUE PL  CHICAGO    IL   60611.0  ...
# ...

# %%
#create conncetion to MongoDB
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
#create restaurantsDB mongo database
#create the liquor license collection
db = client.restaurantsDB
collection = db.liquor

# %%
#remove NaN and filling with empty string
liquor_license_df = liquor_license_df.fillna('')
liquor_license_df.head()
# Out:
#                  id license id  account number  site number  \
# 5  2550102-20170803  2,550,102          408343            1
# 6  2423997-20170619  2,423,997          401191            1
# 7  1800741-20170316  2,507,270           11400            1
# 8  1739261-20170316  2,509,086          307041            1
# 9  1226890-20170316  2,508,287          201786            1
#
#                legal name      doing business as name  \
# 5       VOICE OF THE CITY           VOICE OF THE CITY
# 6             MAGO RC LLC        MAGO GRILL & CANTINA
# 7  FORTNIGHTLY OF CHICAGO  THE FORTNIGHTLY OF CHICAGO
# 8     MCCLURG CORPORATION                   7- ELEVEN
# 9        3343 CLARK CORP.                  LOWCOUNTRY
#
#                             address     city state zip code  ...  \
# 5  3429 W DIVERSEY AVE 2ND/REAR 209  CHICAGO    IL    60647  ...
# 6      1010 S DELANO WEST CT 1 G131  CHICAGO    IL    60605  ...
# 7                 120 E BELLEVUE PL  CHICAGO    IL    60611  ...
# ...

# %%
#put liquor_license_df in list of dictionaries then insert list of dictionaries into collection
db.collection.insert_many(liquor_license_df.to_dict('records'))

# %%
#print each liquor license and corresponding data across row
liquor_licenses = db.liquor.find()
for liquor_license in liquor_licenses:
    print(liquor_license)
